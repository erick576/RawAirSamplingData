# %%
import pandas as pd
import seaborn as sns
import sys
import numpy as np
from matplotlib import pyplot as plt

# %%
colnames = ['Date', 'Time', 'PM2.5(µg/m3)', 'O3(ppb)', 'Benzene(ppb)']
df = pd.read_csv('ESSE221-ProjectRawData.csv', names=colnames, skiprows=1)

# %%
df2 = df[~df["PM2.5(µg/m3)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib'])]
plt.figure(figsize=(20,20))
plt.xlabel("Date & Time", size = 30)
plt.ylabel("PM2.5 (µg/m3)", size = 30)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xticks(np.arange(0, 8510, 800), rotation='vertical')
df2["PM2.5(µg/m3)"] = pd.to_numeric(df2["PM2.5(µg/m3)"])
combined_date = df2["Date"].astype(str) + " " + df2["Time"].astype(str)
plt.plot(combined_date,  df2["PM2.5(µg/m3)"], color='blue')
plt.title("Date & Time vs. PM2.5(µg/m3)", size = 30)
# Out:
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Text(0.5, 1.0, 'Date & Time vs. PM2.5(µg/m3)')

# %%
df2 = df[~df["O3(ppb)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib'])]
plt.figure(figsize=(20,20))
plt.xlabel("Date & Time", size = 30)
plt.ylabel("O3 (ppb)", size = 30)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xticks(np.arange(0, 8510, 800), rotation='vertical')
df2["O3(ppb)"] = pd.to_numeric(df2["O3(ppb)"])
combined_date = df2["Date"].astype(str) + " " + df2["Time"].astype(str)
plt.plot(combined_date,  df2["O3(ppb)"], color='red')
plt.title("Date & Time vs. O3(ppb)", size = 30)
# Out:
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Text(0.5, 1.0, 'Date & Time vs. O3(ppb)')

# %%
df2 = df[~df["Benzene(ppb)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib', 'pwrfail', 'cal', 'down', 'pwrfl'])]
plt.figure(figsize=(20,20))
plt.xlabel("Date & Time", size = 30)
plt.ylabel("Benzene (ppb)", size = 30)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xticks(np.arange(0, 8510, 800), rotation='vertical')
df2["Benzene(ppb)"] = pd.to_numeric(df2["Benzene(ppb)"])
combined_date = df2["Date"].astype(str) + " " + df2["Time"].astype(str)
plt.plot(combined_date,  df2["Benzene(ppb)"], color='green')
plt.title("Date & Time vs. Benzene(ppb)", size = 30)
# Out:
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Text(0.5, 1.0, 'Date & Time vs. Benzene(ppb)')

# %%
df2 = df[~df["PM2.5(µg/m3)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib'])]
df3 = df2.loc[df2['Date'].str.contains("Jan", case=True)]
plt.figure(figsize=(20,20))
plt.xlabel("Date & Time", size = 30)
plt.ylabel("PM2.5 (µg/m3)", size = 30)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xticks(np.arange(0, 617, 100), rotation='vertical')
df3["PM2.5(µg/m3)"] = pd.to_numeric(df3["PM2.5(µg/m3)"])
combined_date = df3["Date"].astype(str) + " " + df3["Time"].astype(str)
plt.plot(combined_date,  df3["PM2.5(µg/m3)"], color='blue')
plt.title("Date & Time vs. PM2.5(µg/m3) In January", size = 30)
# Out:
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# Text(0.5, 1.0, 'Date & Time vs. PM2.5(µg/m3) In January')

# %%
df2 = df[~df["O3(ppb)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib'])]
df3 = df2.loc[df2['Date'].str.contains("Jan", case=True)]
plt.figure(figsize=(20,20))
plt.xlabel("Date & Time", size = 30)
plt.ylabel("O3 (ppb)", size = 30)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xticks(np.arange(0, 617, 100), rotation='vertical')
df3["O3(ppb)"] = pd.to_numeric(df3["O3(ppb)"])
combined_date = df3["Date"].astype(str) + " " + df3["Time"].astype(str)
plt.plot(combined_date,  df3["O3(ppb)"], color='red')
plt.title("Date & Time vs. O3(ppb) In January", size = 30)
# Out:
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# Text(0.5, 1.0, 'Date & Time vs. O3(ppb) In January')

# %%
df2 = df[~df["Benzene(ppb)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib', 'pwrfail', 'cal', 'down', 'pwrfl'])]
df3 = df2.loc[df2['Date'].str.contains("Jan", case=True)]
plt.figure(figsize=(20,20))
plt.xlabel("Date & Time", size = 30)
plt.ylabel("Benzene (ppb)", size = 30)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xticks(np.arange(0, 617, 100), rotation='vertical')
df3["Benzene(ppb)"] = pd.to_numeric(df3["Benzene(ppb)"])
combined_date = df3["Date"].astype(str) + " " + df3["Time"].astype(str)
plt.plot(combined_date,  df3["Benzene(ppb)"], color='green')
plt.title("Date & Time vs. Benzene(ppb) In January", size = 30)
# Out:
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# Text(0.5, 1.0, 'Date & Time vs. Benzene(ppb) In January')

# %%
# Can Adjust Graphs Above to Show the changes for different specific months as well

# %%
plt.figure(figsize=(20,20))
df2 = df[~df["PM2.5(µg/m3)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib'])]

df3 = df2.loc[df2['Date'].str.contains("Jan", case=True)]
df3["PM2.5(µg/m3)"] = pd.to_numeric(df3["PM2.5(µg/m3)"])
jan_val = df3['PM2.5(µg/m3)'].sum()

df4 = df2.loc[df2['Date'].str.contains("Feb", case=True)]
df4["PM2.5(µg/m3)"] = pd.to_numeric(df4["PM2.5(µg/m3)"])
feb_val = df4['PM2.5(µg/m3)'].sum()

df5 = df2.loc[df2['Date'].str.contains("Mar", case=True)]
df5["PM2.5(µg/m3)"] = pd.to_numeric(df5["PM2.5(µg/m3)"])
mar_val = df5['PM2.5(µg/m3)'].sum()

df6 = df2.loc[df2['Date'].str.contains("Apr", case=True)]
df6["PM2.5(µg/m3)"] = pd.to_numeric(df6["PM2.5(µg/m3)"])
apr_val = df6['PM2.5(µg/m3)'].sum()

df7 = df2.loc[df2['Date'].str.contains("May", case=True)]
df7["PM2.5(µg/m3)"] = pd.to_numeric(df7["PM2.5(µg/m3)"])
may_val = df7['PM2.5(µg/m3)'].sum()

df8 = df2.loc[df2['Date'].str.contains("Jun", case=True)]
df8["PM2.5(µg/m3)"] = pd.to_numeric(df8["PM2.5(µg/m3)"])
jun_val = df8['PM2.5(µg/m3)'].sum()

df9 = df2.loc[df2['Date'].str.contains("Jul", case=True)]
df9["PM2.5(µg/m3)"] = pd.to_numeric(df9["PM2.5(µg/m3)"])
jul_val = df9['PM2.5(µg/m3)'].sum()

df10 = df2.loc[df2['Date'].str.contains("Aug", case=True)]
df10["PM2.5(µg/m3)"] = pd.to_numeric(df10["PM2.5(µg/m3)"])
aug_val = df10['PM2.5(µg/m3)'].sum()

df11 = df2.loc[df2['Date'].str.contains("Sep", case=True)]
df11["PM2.5(µg/m3)"] = pd.to_numeric(df11["PM2.5(µg/m3)"])
sept_val = df11['PM2.5(µg/m3)'].sum()

df12 = df2.loc[df2['Date'].str.contains("Oct", case=True)]
df12["PM2.5(µg/m3)"] = pd.to_numeric(df12["PM2.5(µg/m3)"])
oct_val = df12['PM2.5(µg/m3)'].sum()

df13 = df2.loc[df2['Date'].str.contains("Nov", case=True)]
df13["PM2.5(µg/m3)"] = pd.to_numeric(df13["PM2.5(µg/m3)"])
nov_val = df13['PM2.5(µg/m3)'].sum()

df14 = df2.loc[df2['Date'].str.contains("Dec", case=True)]
df14["PM2.5(µg/m3)"] = pd.to_numeric(df14["PM2.5(µg/m3)"])
dec_val = df14['PM2.5(µg/m3)'].sum()

total=[jan_val, feb_val, mar_val, apr_val, may_val, jun_val, jul_val, aug_val, sept_val, oct_val, nov_val, dec_val]
index=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']

plt.pie(total,labels=index,autopct='%1.1f%%')
plt.title('Monthly Totals of PM2.5(µg/m3)', size=30,  pad=30)
plt.axis('equal')
plt.fontsize(20)
plt.show()
# Out:
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
plt.figure(figsize=(20,20))
df2 = df[~df["O3(ppb)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib'])]

df3 = df2.loc[df2['Date'].str.contains("Jan", case=True)]
df3["O3(ppb)"] = pd.to_numeric(df3["O3(ppb)"])
jan_val = df3['O3(ppb)'].sum()

df4 = df2.loc[df2['Date'].str.contains("Feb", case=True)]
df4["O3(ppb)"] = pd.to_numeric(df4["O3(ppb)"])
feb_val = df4['O3(ppb)'].sum()

df5 = df2.loc[df2['Date'].str.contains("Mar", case=True)]
df5["O3(ppb)"] = pd.to_numeric(df5["O3(ppb)"])
mar_val = df5['O3(ppb)'].sum()

df6 = df2.loc[df2['Date'].str.contains("Apr", case=True)]
df6["O3(ppb)"] = pd.to_numeric(df6["O3(ppb)"])
apr_val = df6['O3(ppb)'].sum()

df7 = df2.loc[df2['Date'].str.contains("May", case=True)]
df7["O3(ppb)"] = pd.to_numeric(df7["O3(ppb)"])
may_val = df7['O3(ppb)'].sum()

df8 = df2.loc[df2['Date'].str.contains("Jun", case=True)]
df8["O3(ppb)"] = pd.to_numeric(df8["O3(ppb)"])
jun_val = df8['O3(ppb)'].sum()

df9 = df2.loc[df2['Date'].str.contains("Jul", case=True)]
df9["O3(ppb)"] = pd.to_numeric(df9["O3(ppb)"])
jul_val = df9['O3(ppb)'].sum()

df10 = df2.loc[df2['Date'].str.contains("Aug", case=True)]
df10["O3(ppb)"] = pd.to_numeric(df10["O3(ppb)"])
aug_val = df10['O3(ppb)'].sum()

df11 = df2.loc[df2['Date'].str.contains("Sep", case=True)]
df11["O3(ppb)"] = pd.to_numeric(df11["O3(ppb)"])
sept_val = df11['O3(ppb)'].sum()

df12 = df2.loc[df2['Date'].str.contains("Oct", case=True)]
df12["O3(ppb)"] = pd.to_numeric(df12["O3(ppb)"])
oct_val = df12['O3(ppb)'].sum()

df13 = df2.loc[df2['Date'].str.contains("Nov", case=True)]
df13["O3(ppb)"] = pd.to_numeric(df13["O3(ppb)"])
nov_val = df13['O3(ppb)'].sum()

df14 = df2.loc[df2['Date'].str.contains("Dec", case=True)]
df14["O3(ppb)"] = pd.to_numeric(df14["O3(ppb)"])
dec_val = df14['O3(ppb)'].sum()

total=[jan_val, feb_val, mar_val, apr_val, may_val, jun_val, jul_val, aug_val, sept_val, oct_val, nov_val, dec_val]
index=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']

plt.pie(total,labels=index,autopct='%1.1f%%')
plt.title('Monthly Totals of O3(ppb)', size=30,  pad=30)
plt.axis('equal')
plt.fontsize(20)
plt.show()
# Out:
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
plt.figure(figsize=(20,20))
df2 = df[~df["Benzene(ppb)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib', 'pwrfail', 'cal', 'down', 'pwrfl'])]

df3 = df2.loc[df2['Date'].str.contains("Jan", case=True)]
df3["Benzene(ppb)"] = pd.to_numeric(df3["Benzene(ppb)"])
jan_val = df3['Benzene(ppb)'].sum()

df4 = df2.loc[df2['Date'].str.contains("Feb", case=True)]
df4["Benzene(ppb)"] = pd.to_numeric(df4["Benzene(ppb)"])
feb_val = df4['Benzene(ppb)'].sum()

df5 = df2.loc[df2['Date'].str.contains("Mar", case=True)]
df5["Benzene(ppb)"] = pd.to_numeric(df5["Benzene(ppb)"])
mar_val = df5['Benzene(ppb)'].sum()

df6 = df2.loc[df2['Date'].str.contains("Apr", case=True)]
df6["Benzene(ppb)"] = pd.to_numeric(df6["Benzene(ppb)"])
apr_val = df6['Benzene(ppb)'].sum()

df7 = df2.loc[df2['Date'].str.contains("May", case=True)]
df7["Benzene(ppb)"] = pd.to_numeric(df7["Benzene(ppb)"])
may_val = df7['Benzene(ppb)'].sum()

df8 = df2.loc[df2['Date'].str.contains("Jun", case=True)]
df8["Benzene(ppb)"] = pd.to_numeric(df8["Benzene(ppb)"])
jun_val = df8['Benzene(ppb)'].sum()

df9 = df2.loc[df2['Date'].str.contains("Jul", case=True)]
df9["Benzene(ppb)"] = pd.to_numeric(df9["Benzene(ppb)"])
jul_val = df9['Benzene(ppb)'].sum()

df10 = df2.loc[df2['Date'].str.contains("Aug", case=True)]
df10["Benzene(ppb)"] = pd.to_numeric(df10["Benzene(ppb)"])
aug_val = df10['Benzene(ppb)'].sum()

df11 = df2.loc[df2['Date'].str.contains("Sep", case=True)]
df11["Benzene(ppb)"] = pd.to_numeric(df11["Benzene(ppb)"])
sept_val = df11['Benzene(ppb)'].sum()

df12 = df2.loc[df2['Date'].str.contains("Oct", case=True)]
df12["Benzene(ppb)"] = pd.to_numeric(df12["Benzene(ppb)"])
oct_val = df12['Benzene(ppb)'].sum()

df13 = df2.loc[df2['Date'].str.contains("Nov", case=True)]
df13["Benzene(ppb)"] = pd.to_numeric(df13["Benzene(ppb)"])
nov_val = df13['Benzene(ppb)'].sum()

df14 = df2.loc[df2['Date'].str.contains("Dec", case=True)]
df14["Benzene(ppb)"] = pd.to_numeric(df14["Benzene(ppb)"])
dec_val = df14['Benzene(ppb)'].sum()

total=[jan_val, feb_val, mar_val, apr_val, may_val, jun_val, jul_val, aug_val, sept_val, oct_val, nov_val, dec_val]
index=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']

plt.pie(total,labels=index,autopct='%1.1f%%')
plt.title('Monthly Totals of Benzene(ppb)', size=30,  pad=30)
plt.axis('equal')
plt.fontsize(20)
plt.show()
# Out:
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df2 = df[~df["PM2.5(µg/m3)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib'])]
df3 = df2.loc[df2['Date'].str.contains("01-Feb-19", case=True)]
plt.figure(figsize=(20,20))
plt.xlabel("Time", size = 30)
plt.ylabel("PM2.5 (µg/m3)", size = 30)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xticks(rotation='vertical')
df3["PM2.5(µg/m3)"] = pd.to_numeric(df3["PM2.5(µg/m3)"])
plt.plot(df3['Time'],  df3["PM2.5(µg/m3)"], color='blue')
plt.title("Hourly PM2.5(µg/m3) on 01 Feb 2019", size = 30)
# Out:
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# Text(0.5, 1.0, 'Hourly PM2.5(µg/m3) on 01 Feb 2019')

# %%
df2 = df[~df["O3(ppb)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib'])]
df3 = df2.loc[df2['Date'].str.contains("01-Feb-19", case=True)]
plt.figure(figsize=(20,20))
plt.xlabel("Time", size = 30)
plt.ylabel("O3(ppb)", size = 30)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xticks(rotation='vertical')
df3["O3(ppb)"] = pd.to_numeric(df3["O3(ppb)"])
plt.plot(df3['Time'],  df3["O3(ppb)"], color='red')
plt.title("Hourly O3(ppb) on 01 Feb 2019", size = 30)
# Out:
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# Text(0.5, 1.0, 'Hourly O3(ppb) on 01 Feb 2019')

# %%
df2 = df[~df["Benzene(ppb)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib', 'pwrfail', 'cal', 'down', 'pwrfl'])]
df3 = df2.loc[df2['Date'].str.contains("01-Feb-19", case=True)]
plt.figure(figsize=(20,20))
plt.xlabel("Time", size = 30)
plt.ylabel("Benzene(ppb)", size = 30)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xticks(rotation='vertical')
df3["Benzene(ppb)"] = pd.to_numeric(df3["Benzene(ppb)"])
plt.plot(df3['Time'],  df3["Benzene(ppb)"], color='green')
plt.title("Hourly Benzene(ppb) on 01 Feb 2019", size = 30)
# Out:
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# Text(0.5, 1.0, 'Hourly Benzene(ppb) on 01 Feb 2019')

# %%
# Total Min, Max, Median, Mean
print("Total Aggregations\n")

df2 = df[~df["PM2.5(µg/m3)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib', 'pwrfail', 'cal', 'down', 'pwrfl'])]
df3 = df[~df["O3(ppb)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib', 'pwrfail', 'cal', 'down', 'pwrfl'])]
df4 = df[~df["Benzene(ppb)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib', 'pwrfail', 'cal', 'down', 'pwrfl'])]
df2["PM2.5(µg/m3)"] = pd.to_numeric(df2["PM2.5(µg/m3)"])
df3["O3(ppb)"] = pd.to_numeric(df3["O3(ppb)"])
df4["Benzene(ppb)"] = pd.to_numeric(df4["Benzene(ppb)"])

print("Min PM2.5(µg/m3): " + str(df2["PM2.5(µg/m3)"].min()) + "\n")
print("Min O3(ppb): " + str(df3["O3(ppb)"].min()) + "\n")
print("Min Benzene(ppb): " + str(df4["Benzene(ppb)"].min()) + "\n")

print("Max PM2.5(µg/m3): " + str(df2["PM2.5(µg/m3)"].max()) + "\n")
print("Max O3(ppb): " + str(df3["O3(ppb)"].max()) + "\n")
print("Max Benzene(ppb): " + str(df4["Benzene(ppb)"].max()) + "\n")

print("Mean PM2.5(µg/m3): " + str(df2["PM2.5(µg/m3)"].mean()) + "\n")
print("Mean O3(ppb): " + str(df3["O3(ppb)"].mean()) + "\n")
print("Mean Benzene(ppb): " + str(df4["Benzene(ppb)"].mean()) + "\n")

print("Median PM2.5(µg/m3): " + str(df2["PM2.5(µg/m3)"].median()) + "\n")
print("Median O3(ppb): " + str(df3["O3(ppb)"].median()) + "\n")
print("Median Benzene(ppb): " + str(df4["Benzene(ppb)"].median()) + "\n")
# Out:
# Total Aggregations
#
# Min PM2.5(µg/m3): 0
#
# Min O3(ppb): 0
#
# Min Benzene(ppb): 0.0
#
# Max PM2.5(µg/m3): 62
#
# Max O3(ppb): 82
#
# Max Benzene(ppb): 18.24
#
# Mean PM2.5(µg/m3): 8.143713278495888
#
# Mean O3(ppb): 27.470818505338077
#
# Mean Benzene(ppb): 0.21016323024054984
#
# Median PM2.5(µg/m3): 6.0
#
# Median O3(ppb): 28.0
#
# Median Benzene(ppb): 0.0
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
plt.figure(figsize=(20,20))
df2 = df[~df["PM2.5(µg/m3)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib'])]

df3 = df2.loc[df2['Date'].str.contains("Jan", case=True)]
df3["PM2.5(µg/m3)"] = pd.to_numeric(df3["PM2.5(µg/m3)"])
jan_val = df3['PM2.5(µg/m3)'].sum()
jan_count = df3['PM2.5(µg/m3)'].count()
jan_mean = jan_val / jan_count

df4 = df2.loc[df2['Date'].str.contains("Feb", case=True)]
df4["PM2.5(µg/m3)"] = pd.to_numeric(df4["PM2.5(µg/m3)"])
feb_val = df4['PM2.5(µg/m3)'].sum()
feb_count = df4['PM2.5(µg/m3)'].count()
feb_mean = feb_val / feb_count

df5 = df2.loc[df2['Date'].str.contains("Mar", case=True)]
df5["PM2.5(µg/m3)"] = pd.to_numeric(df5["PM2.5(µg/m3)"])
mar_val = df5['PM2.5(µg/m3)'].sum()
mar_count = df5['PM2.5(µg/m3)'].count()
mar_mean = mar_val / mar_count

df6 = df2.loc[df2['Date'].str.contains("Apr", case=True)]
df6["PM2.5(µg/m3)"] = pd.to_numeric(df6["PM2.5(µg/m3)"])
apr_val = df6['PM2.5(µg/m3)'].sum()
apr_count = df6['PM2.5(µg/m3)'].count()
apr_mean = apr_val / apr_count

df7 = df2.loc[df2['Date'].str.contains("May", case=True)]
df7["PM2.5(µg/m3)"] = pd.to_numeric(df7["PM2.5(µg/m3)"])
may_val = df7['PM2.5(µg/m3)'].sum()
may_count = df7['PM2.5(µg/m3)'].count()
may_mean = may_val / may_count

df8 = df2.loc[df2['Date'].str.contains("Jun", case=True)]
df8["PM2.5(µg/m3)"] = pd.to_numeric(df8["PM2.5(µg/m3)"])
jun_val = df8['PM2.5(µg/m3)'].sum()
jun_count = df8['PM2.5(µg/m3)'].count()
jun_mean = jun_val / jun_count

df9 = df2.loc[df2['Date'].str.contains("Jul", case=True)]
df9["PM2.5(µg/m3)"] = pd.to_numeric(df9["PM2.5(µg/m3)"])
jul_val = df9['PM2.5(µg/m3)'].sum()
jul_count = df9['PM2.5(µg/m3)'].count()
jul_mean = jul_val / jul_count

df10 = df2.loc[df2['Date'].str.contains("Aug", case=True)]
df10["PM2.5(µg/m3)"] = pd.to_numeric(df10["PM2.5(µg/m3)"])
aug_val = df10['PM2.5(µg/m3)'].sum()
aug_count = df10['PM2.5(µg/m3)'].count()
aug_mean = aug_val / aug_count

df11 = df2.loc[df2['Date'].str.contains("Sep", case=True)]
df11["PM2.5(µg/m3)"] = pd.to_numeric(df11["PM2.5(µg/m3)"])
sept_val = df11['PM2.5(µg/m3)'].sum()
sept_count = df11['PM2.5(µg/m3)'].count()
sept_mean = sept_val / sept_count

df12 = df2.loc[df2['Date'].str.contains("Oct", case=True)]
df12["PM2.5(µg/m3)"] = pd.to_numeric(df12["PM2.5(µg/m3)"])
oct_val = df12['PM2.5(µg/m3)'].sum()
oct_count = df12['PM2.5(µg/m3)'].count()
oct_mean = oct_val / oct_count

df13 = df2.loc[df2['Date'].str.contains("Nov", case=True)]
df13["PM2.5(µg/m3)"] = pd.to_numeric(df13["PM2.5(µg/m3)"])
nov_val = df13['PM2.5(µg/m3)'].sum()
nov_count = df13['PM2.5(µg/m3)'].count()
nov_mean = nov_val / nov_count

df14 = df2.loc[df2['Date'].str.contains("Dec", case=True)]
df14["PM2.5(µg/m3)"] = pd.to_numeric(df14["PM2.5(µg/m3)"])
dec_val = df14['PM2.5(µg/m3)'].sum()
dec_count = df14['PM2.5(µg/m3)'].count()
dec_mean = dec_val / dec_count

total=[jan_mean, feb_mean, mar_mean, apr_mean, may_mean, jun_mean, jul_mean, aug_mean, sept_mean, oct_mean, nov_mean, dec_mean]
index=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']

plt.bar(index, total, color='b')
plt.title('Monthly Means of PM2.5(µg/m3)', size=30,  pad=30)
plt.xlabel("Month", size = 30)
plt.ylabel("PM2.5 (µg/m3)", size = 30)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.fontsize(20)
plt.show()
# Out:
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
plt.figure(figsize=(20,20))
df2 = df[~df["O3(ppb)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib'])]

df3 = df2.loc[df2['Date'].str.contains("Jan", case=True)]
df3["O3(ppb)"] = pd.to_numeric(df3["O3(ppb)"])
jan_val = df3['O3(ppb)'].sum()
jan_count = df3["O3(ppb)"].count()
jan_mean = jan_val / jan_count

df4 = df2.loc[df2['Date'].str.contains("Feb", case=True)]
df4["O3(ppb)"] = pd.to_numeric(df4["O3(ppb)"])
feb_val = df4['O3(ppb)'].sum()
feb_count = df4['O3(ppb)'].count()
feb_mean = feb_val / feb_count

df5 = df2.loc[df2['Date'].str.contains("Mar", case=True)]
df5["O3(ppb)"] = pd.to_numeric(df5["O3(ppb)"])
mar_val = df5['O3(ppb)'].sum()
mar_count = df5['O3(ppb)'].count()
mar_mean = mar_val / mar_count

df6 = df2.loc[df2['Date'].str.contains("Apr", case=True)]
df6["O3(ppb)"] = pd.to_numeric(df6["O3(ppb)"])
apr_val = df6['O3(ppb)'].sum()
apr_count = df6['O3(ppb)'].count()
apr_mean = apr_val / apr_count

df7 = df2.loc[df2['Date'].str.contains("May", case=True)]
df7["O3(ppb)"] = pd.to_numeric(df7["O3(ppb)"])
may_val = df7['O3(ppb)'].sum()
may_count = df7['O3(ppb)'].count()
may_mean = may_val / may_count

df8 = df2.loc[df2['Date'].str.contains("Jun", case=True)]
df8["O3(ppb)"] = pd.to_numeric(df8["O3(ppb)"])
jun_val = df8['O3(ppb)'].sum()
jun_count = df8['O3(ppb)'].count()
jun_mean = jun_val / jun_count

df9 = df2.loc[df2['Date'].str.contains("Jul", case=True)]
df9["O3(ppb)"] = pd.to_numeric(df9["O3(ppb)"])
jul_val = df9['O3(ppb)'].sum()
jul_count = df9['O3(ppb)'].count()
jul_mean = jul_val / jul_count

df10 = df2.loc[df2['Date'].str.contains("Aug", case=True)]
df10["O3(ppb)"] = pd.to_numeric(df10["O3(ppb)"])
aug_val = df10['O3(ppb)'].sum()
aug_count = df10['O3(ppb)'].count()
aug_mean = aug_val / aug_count

df11 = df2.loc[df2['Date'].str.contains("Sep", case=True)]
df11["O3(ppb)"] = pd.to_numeric(df11["O3(ppb)"])
sept_val = df11['O3(ppb)'].sum()
sept_count = df11['O3(ppb)'].count()
sept_mean = sept_val / sept_count

df12 = df2.loc[df2['Date'].str.contains("Oct", case=True)]
df12["O3(ppb)"] = pd.to_numeric(df12["O3(ppb)"])
oct_val = df12['O3(ppb)'].sum()
oct_count = df12['O3(ppb)'].count()
oct_mean = oct_val / oct_count

df13 = df2.loc[df2['Date'].str.contains("Nov", case=True)]
df13["O3(ppb)"] = pd.to_numeric(df13["O3(ppb)"])
nov_val = df13['O3(ppb)'].sum()
nov_count = df13['O3(ppb)'].count()
nov_mean = nov_val / nov_count

df14 = df2.loc[df2['Date'].str.contains("Dec", case=True)]
df14["O3(ppb)"] = pd.to_numeric(df14["O3(ppb)"])
dec_val = df14['O3(ppb)'].sum()
dec_count = df14['O3(ppb)'].count()
dec_mean = dec_val / dec_count

total=[jan_mean, feb_mean, mar_mean, apr_mean, may_mean, jun_mean, jul_mean, aug_mean, sept_mean, oct_mean, nov_mean, dec_mean]
index=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']

plt.bar(index, total, color='r')
plt.title('Monthly Means of O3(ppb)', size=30,  pad=30)
plt.xlabel("Month", size = 30)
plt.ylabel("O3 (ppb)", size = 30)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.fontsize(20)
plt.show()
# Out:
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
plt.figure(figsize=(20,20))
df2 = df[~df["Benzene(ppb)"].isin(['<Samp','NoData', 'NoData', 'InVld', 'Down', 'Calib', 'pwrfail', 'cal', 'down', 'pwrfl'])]

df3 = df2.loc[df2['Date'].str.contains("Jan", case=True)]
df3["Benzene(ppb)"] = pd.to_numeric(df3["Benzene(ppb)"])
jan_val = df3['Benzene(ppb)'].sum()
jan_count = df3["Benzene(ppb)"].count()
jan_mean = jan_val / jan_count

df4 = df2.loc[df2['Date'].str.contains("Feb", case=True)]
df4["Benzene(ppb)"] = pd.to_numeric(df4["Benzene(ppb)"])
feb_val = df4['Benzene(ppb)'].sum()
feb_count = df4['Benzene(ppb)'].count()
feb_mean = feb_val / feb_count

df5 = df2.loc[df2['Date'].str.contains("Mar", case=True)]
df5["Benzene(ppb)"] = pd.to_numeric(df5["Benzene(ppb)"])
mar_val = df5['Benzene(ppb)'].sum()
mar_count = df5['Benzene(ppb)'].count()
mar_mean = mar_val / mar_count

df6 = df2.loc[df2['Date'].str.contains("Apr", case=True)]
df6["Benzene(ppb)"] = pd.to_numeric(df6["Benzene(ppb)"])
apr_val = df6['Benzene(ppb)'].sum()
apr_count = df6['Benzene(ppb)'].count()
apr_mean = apr_val / apr_count

df7 = df2.loc[df2['Date'].str.contains("May", case=True)]
df7["Benzene(ppb)"] = pd.to_numeric(df7["Benzene(ppb)"])
may_val = df7['Benzene(ppb)'].sum()
may_count = df7['Benzene(ppb)'].count()
may_mean = may_val / may_count

df8 = df2.loc[df2['Date'].str.contains("Jun", case=True)]
df8["Benzene(ppb)"] = pd.to_numeric(df8["Benzene(ppb)"])
jun_val = df8['Benzene(ppb)'].sum()
jun_count = df8['Benzene(ppb)'].count()
jun_mean = jun_val / jun_count

df9 = df2.loc[df2['Date'].str.contains("Jul", case=True)]
df9["Benzene(ppb)"] = pd.to_numeric(df9["Benzene(ppb)"])
jul_val = df9['Benzene(ppb)'].sum()
jul_count = df9['Benzene(ppb)'].count()
jul_mean = jul_val / jul_count

df10 = df2.loc[df2['Date'].str.contains("Aug", case=True)]
df10["Benzene(ppb)"] = pd.to_numeric(df10["Benzene(ppb)"])
aug_val = df10['Benzene(ppb)'].sum()
aug_count = df10['Benzene(ppb)'].count()
aug_mean = aug_val / aug_count

df11 = df2.loc[df2['Date'].str.contains("Sep", case=True)]
df11["Benzene(ppb)"] = pd.to_numeric(df11["Benzene(ppb)"])
sept_val = df11['Benzene(ppb)'].sum()
sept_count = df11['Benzene(ppb)'].count()
sept_mean = sept_val / sept_count

df12 = df2.loc[df2['Date'].str.contains("Oct", case=True)]
df12["Benzene(ppb)"] = pd.to_numeric(df12["Benzene(ppb)"])
oct_val = df12['Benzene(ppb)'].sum()
oct_count = df12['Benzene(ppb)'].count()
oct_mean = oct_val / oct_count

df13 = df2.loc[df2['Date'].str.contains("Nov", case=True)]
df13["Benzene(ppb)"] = pd.to_numeric(df13["Benzene(ppb)"])
nov_val = df13['Benzene(ppb)'].sum()
nov_count = df13['Benzene(ppb)'].count()
nov_mean = nov_val / nov_count

df14 = df2.loc[df2['Date'].str.contains("Dec", case=True)]
df14["Benzene(ppb)"] = pd.to_numeric(df14["Benzene(ppb)"])
dec_val = df14['Benzene(ppb)'].sum()
dec_count = df14['Benzene(ppb)'].count()
dec_mean = dec_val / dec_count

total=[jan_mean, feb_mean, mar_mean, apr_mean, may_mean, jun_mean, jul_mean, aug_mean, sept_mean, oct_mean, nov_mean, dec_mean]
index=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']

plt.bar(index, total, color='g')
plt.title('Monthly Means of Benzene(ppb)', size=30,  pad=30)
plt.xlabel("Month", size = 30)
plt.ylabel("Benzene (ppb)", size = 30)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.fontsize(20)
plt.show()
# Out:
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Ericn\miniconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
